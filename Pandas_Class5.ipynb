# %% [markdown]
# # 🐼 Pandas - Class 5: Sorting & Basic Statistics
# Welcome to **Class 5** of our Pandas series. Today we’ll learn how to sort data and calculate basic statistics.

# %% [markdown]
# ## 1. Sorting Data
# - Use `sort_values(by='col')` to sort by column values.
# - Use `ascending=False` for descending order.
# - Sort by multiple columns by passing a list.
# - `sort_index()` sorts by row or column index.

# %%
import pandas as pd
data={
    "Product": ["Pen","Notebook","Pencil","Eraser","Ruler","Marker"],
    "Price": [10,20,30,40,5,8],
    "Stock": [100,60,30,150,20,50],
    "Rating": [4.6,4.4,3.4,4.1,4.5,4.8]
}
df = pd.DataFrame(data)
df
# Out:
#     Product  Price  Stock  Rating
# 0       Pen     10    100     4.6
# 1  Notebook     20     60     4.4
# 2    Pencil     30     30     3.4
# 3    Eraser     40    150     4.1
# 4     Ruler      5     20     4.5
# 5    Marker      8     50     4.8

# %%
df.sort_values(by='Price')
# Out:
#     Product  Price  Stock  Rating
# 4     Ruler      5     20     4.5
# 5    Marker      8     50     4.8
# 0       Pen     10    100     4.6
# 1  Notebook     20     60     4.4
# 2    Pencil     30     30     3.4
# 3    Eraser     40    150     4.1

# %%
 #sort bu multiple columns (price ascending then stock descending)
df.sort_values(by=['Price','Stock'],ascending=[True,False])
# Out:
#     Product  Price  Stock  Rating
# 4     Ruler      5     20     4.5
# 5    Marker      8     50     4.8
# 0       Pen     10    100     4.6
# 1  Notebook     20     60     4.4
# 2    Pencil     30     30     3.4
# 3    Eraser     40    150     4.1

# %% [markdown]
# ## 2. Descriptive Statistics
# - `mean()`, `median()`, `mode()` for central tendency.
# - `std()` for standard deviation.
# - `describe()` for a summary of stats (count, mean, std, min, quartiles, max).

# %%
df.mean(numeric_only=True)
# Out:
# Price     18.833333
# Stock     68.333333
# Rating     4.300000
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Price     15.00
# Stock     55.00
# Rating     4.45
# dtype: float64

# %%
df.mode()
# Out:
#     Product  Price  Stock  Rating
# 0    Eraser      5     20     3.4
# 1    Marker      8     30     4.1
# 2  Notebook     10     50     4.4
# 3       Pen     20     60     4.5
# 4    Pencil     30    100     4.6
# 5     Ruler     40    150     4.8

# %%
df.describe()
# Out:
#            Price       Stock    Rating
# count   6.000000    6.000000  6.000000
# mean   18.833333   68.333333  4.300000
# std    13.862419   48.751068  0.497996
# min     5.000000   20.000000  3.400000
# 25%     8.500000   35.000000  4.175000
# 50%    15.000000   55.000000  4.450000
# 75%    27.500000   90.000000  4.575000
# max    40.000000  150.000000  4.800000

# %% [markdown]
# ## 3. Counting Values
# - `value_counts()` shows the frequency of unique values in a Series.
# - Use `normalize=True` to see percentages instead of counts.

# %%
df['Product'].value_counts()
# Out:
# Product
# Pen         1
# Notebook    1
# Pencil      1
# Eraser      1
# Ruler       1
# Marker      1
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Correlation & Covariance
# - `corr()` computes correlation between numeric columns.
# - `cov()` computes covariance.
# - Correlation values range from -1 (negative) to +1 (positive).

# %%
df.cov(numeric_only=True)
# Out:
#              Price        Stock  Rating
# Price   192.166667   375.666667  -5.000
# Stock   375.666667  2376.666667   1.600
# Rating   -5.000000     1.600000   0.248

# %%
df.corr(numeric_only=True)
# Out:
#            Price     Stock    Rating
# Price   1.000000  0.555878 -0.724278
# Stock   0.555878  1.000000  0.065904
# Rating -0.724278  0.065904  1.000000

# %%
df['Price'].corr(df['Rating'])
# Out:
# np.float64(-0.7242777361591112)

# %% [markdown]
# ## Mini Practice
# 1. Build a DataFrame with columns: Name, Age, Score, Height.
# 2. Sort the data by Score (descending).
# 3. Get mean, median, mode, and std of numeric columns.
# 4. Use value_counts on Name or any categorical column.
# 5. Compute corr() and cov() for all numeric columns.

# %%
# Write your mini practice solution here

# 1. Build a DataFrame with columns: Name, Age, Score, Height

# 2. Sort the data by Score (descending)
# Write your code here

# 3. Get mean, median, mode, and std of numeric columns
# Write your code here

# 4. Use value_counts on Name or any categorical column
# Write your code here

# 5. Compute corr() and cov() for all numeric columns
# Write your code here

# %% [markdown]
# ---
# ## Summary
# - Learned to sort by columns with `sort_values` and by index with `sort_index`.
# - Explored descriptive statistics: mean, median, mode, std, describe.
# - Counted values with `value_counts`.
# - Calculated correlation and covariance.
