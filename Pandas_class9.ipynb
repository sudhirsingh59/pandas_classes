# %% [markdown]
# # 🐼 Pandas - Class 9: Advanced Tricks & Performance
#
# 1.   List item
# 2.   List item
#
#
# Welcome to **Class 11** of our Pandas series. Today we’ll explore advanced techniques to write efficient, clean, and optimized Pandas code.

# %% [markdown]
# ## 1. Applying Custom Functions with `apply()` / `map()`
# - `apply()` lets you apply a custom function across rows or columns.
# - `map()` is for applying functions element-wise to a Series.
# - Both are handy for transformations, calculations, and cleaning data.

# %%
import pandas as pd
import numpy as np
data = {
    "Name":["Alice","Bob","Charlie","David","Emma"],
    "Math":[65,60,72,88,77],
    "Science":[90,80,78,70,95]
}
df = pd.DataFrame(data)
df
# Out:
#       Name  Math  Science
# 0    Alice    65       90
# 1      Bob    60       80
# 2  Charlie    72       78
# 3    David    88       70
# 4     Emma    77       95

# %%
df['Total Marks'] = df[['Math','Science']].apply(lambda row:row.sum(),axis=1)
df
# Out:
#       Name  Math  Science  Total Marks
# 0    Alice    65       90          155
# 1      Bob    60       80          140
# 2  Charlie    72       78          150
# 3    David    88       70          158
# 4     Emma    77       95          172

# %%
col_mean = df[['Math','Science']].apply(lambda col:col.mean())
col_mean
# Out:
# Math       72.4
# Science    82.6
# dtype: float64

# %%
def to_grade(s):
  if s >= 90:
    return "A"
  elif s >= 80:
    return "B"
  elif s >= 70:
    return "C"
  else:
    return "D"

  df['Maths Grade'] = df['Math'].apply(to_grade)

# %%
df
# Out:
#       Name  Math  Science  Total Marks
# 0    Alice    65       90          155
# 1      Bob    60       80          140
# 2  Charlie    72       78          150
# 3    David    88       70          158
# 4     Emma    77       95          172

# %%
df['Name'] = df['Name'].map(str.lower)
df
# Out:
#       Name  Math  Science  Total Marks
# 0    alice    65       90          155
# 1      bob    60       80          140
# 2  charlie    72       78          150
# 3    david    88       70          158
# 4     emma    77       95          172

# %%
df['bonus Maths'] = df['Math'].map(lambda x : x+5)
df
# Out:
#       Name  Math  Science  Total Marks  bonus Maths
# 0    alice    65       90          155           70
# 1      bob    60       80          140           65
# 2  charlie    72       78          150           77
# 3    david    88       70          158           93
# 4     emma    77       95          172           82
